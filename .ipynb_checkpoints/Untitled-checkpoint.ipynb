# %%
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
data_path = "/home/maksim/ml/datasets/Почищенный датасет с нормализованным эстимейтом - data_set_last7.csv"
data = pd.read_csv(data_path)

# %%
data.head()
# Out:
#     sale_date   Price             Author  \
# 0  10.12.2018   93750  willem de kooning
# 1  10.12.2018   52500  willem de kooning
# 2  05.03.2020  740000   georgia o′keeffe
# 3  10.12.2018    8125        franz kline
# 4  10.12.2018   40000        franz kline
#
#                                      Art Owner  Sign Technique Material  Nazi  \
# 0                       UNTITLED (WOMAN)     -     1       oil    paper     0
# 1                  UNTITLED (STILL LIFE)     -     1       oil    board     0
# 2  UNTITLED (ALLIGATOR PEAR IN RED DISH)     -     0       oil   canvas     0
# 3                               UNTITLED     -     1       oil   canvas     0
# 4                               UNTITLED     -     1       ink    paper     0
#
#    Framed  ... month  year deal_time_(utc)  normalized_price  hasFollowers  \
# 0       0  ...    12  2018           17:00          91630.99             0
# 1       0  ...    12  2018           17:00          91630.99             0
# ...

# %%
data.shape
# Out:
# (14537, 45)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14537 entries, 0 to 14536
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   sale_date                14537 non-null  object
#  1   Price                    14537 non-null  int64
#  2   Author                   14537 non-null  object
#  3   Art                      14537 non-null  object
#  4   Owner                    14537 non-null  object
#  5   Sign                     14537 non-null  int64
#  6   Technique                14537 non-null  object
#  7   Material                 14537 non-null  object
#  8   Nazi                     14537 non-null  int64
#  9   Framed                   14537 non-null  int64
#  10  Size                     14537 non-null  object
#  11  square_m                 14537 non-null  float64
#  12  Currency                 14537 non-null  object
#  13  EstimateFrom             14537 non-null  int64
# ...

# %%
data.describe()
# Out:
#               Price          Sign          Nazi        Framed      square_m  \
# count  1.453700e+04  14537.000000  14537.000000  14537.000000  14537.000000
# mean   1.820069e+06      0.874802      0.006122      0.228245      0.552235
# std    8.020632e+06      0.330954      0.078008      0.419716      0.977473
# min    0.000000e+00      0.000000      0.000000      0.000000      0.000000
# 25%    2.750000e+04      1.000000      0.000000      0.000000      0.128700
# 50%    1.500000e+05      1.000000      0.000000      0.000000      0.309800
# 75%    9.050000e+05      1.000000      0.000000      0.000000      0.609000
# max    5.103710e+08      1.000000      1.000000      1.000000     28.000000
#
#        EstimateFrom    EstimateTo  ExhibitedNum  ProvenanceNum  LiteratureNum  \
# count  1.453700e+04  1.453700e+04  14537.000000   14537.000000   14537.000000
# mean   9.381367e+05  1.327352e+06      1.065488       2.316572       0.979225
# ...

# %%
cor_price = data.corr().Price
cor_price[np.abs(cor_price) > 0.1]
# Out:
# Price                      1.000000
# square_m                   0.311548
# EstimateFrom               0.609508
# EstimateTo                 0.606722
# ExhibitedNum               0.203081
# ProvenanceNum              0.102221
# LiteratureNum              0.266750
# normalized_price           0.425319
# normalized_estimatefrom    0.427860
# normalized_estimateto      0.425319
# Name: Price, dtype: float64
