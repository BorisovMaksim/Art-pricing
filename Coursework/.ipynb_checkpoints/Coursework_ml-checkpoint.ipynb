# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_path = "/home/maksim/datasets/Почищенный датасет с нормализованным эстимейтом - data_set_last7.csv"
data = pd.read_csv(data_path)

# %%
col_to_drop = ["sale_date", "Price","Owner","Size","EstimateFrom","EstimateTo","Time",
            "Description", "tried_url", "Image", "normalized_estimatefrom", 
            "normalized_estimateto"]

data.drop(columns=col_to_drop, inplace=True)

# %%
data.loc[data["normalized_price"] == 0, "normalized_price"] = 10**-10 #To take log
data["log10(normalized_price)"] = np.log10(data["normalized_price"]) 
data.drop(columns=["normalized_price"], inplace=True)

# %%
data.head()
# Out:
#               Author                                    Art  Sign Technique  \
# 0  willem de kooning                       UNTITLED (WOMAN)     1       oil
# 1  willem de kooning                  UNTITLED (STILL LIFE)     1       oil
# 2   georgia o′keeffe  UNTITLED (ALLIGATOR PEAR IN RED DISH)     0       oil
# 3        franz kline                               UNTITLED     1       oil
# 4        franz kline                               UNTITLED     1       ink
#
#   Material  Nazi  Framed  square_m Currency  ExhibitedNum  ...  number_of_day  \
# 0    paper     0       0    0.0925      USD             5  ...            344
# 1    board     0       0    0.0601      USD             3  ...            344
# 2   canvas     0       0    0.0516      USD             0  ...             65
# 3   canvas     0       0    0.1144      USD             1  ...            344
# 4    paper     0       0    0.0590      USD            11  ...            344
#
#    day_of_week  month  year  deal_time_(utc)  hasFollowers  hasAfter  \
# 0       Monday     12  2018            17:00             0         1
# 1       Monday     12  2018            17:00             0         1
# 2     Thursday      3  2020            15:00             0         0
# 3       Monday     12  2018            17:00             0         0
# 4       Monday     12  2018            17:00             0         0
#
#   isUntitled isNumbered log10(normalized_price)
# 0        1.0        1.0                4.962042
# 1        1.0        0.0                4.962042
# 2        1.0        0.0                5.698970
# 3        1.0        0.0                3.910890
# 4        1.0        0.0                4.551868
#
# [5 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14537 entries, 0 to 14536
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Author                   14537 non-null  object
#  1   Art                      14537 non-null  object
#  2   Sign                     14537 non-null  int64
#  3   Technique                14537 non-null  object
#  4   Material                 14537 non-null  object
#  5   Nazi                     14537 non-null  int64
#  6   Framed                   14537 non-null  int64
#  7   square_m                 14537 non-null  float64
#  8   Currency                 14537 non-null  object
#  9   ExhibitedNum             14537 non-null  int64
#  10  ProvenanceNum            14537 non-null  int64
#  11  LiteratureNum            14537 non-null  int64
#  12  CataloguingLength        14537 non-null  int64
#  13  City                     14536 non-null  object
#  14  date_of_birth            14537 non-null  int64
#  15  date_of_death            13435 non-null  float64
#  16  century                  14537 non-null  int64
#  17  nationality              14537 non-null  object
#  18  sex                      14537 non-null  object
#  19  style                    14537 non-null  object
#  20  repeat_sale              14537 non-null  int64
#  21  feature1                 7787 non-null   object
#  22  feature2                 333 non-null    object
#  23  number_of_day            14537 non-null  int64
#  24  day_of_week              14537 non-null  object
#  25  month                    14537 non-null  int64
#  26  year                     14537 non-null  int64
#  27  deal_time_(utc)          14536 non-null  object
#  28  hasFollowers             14537 non-null  int64
#  29  hasAfter                 14537 non-null  int64
#  30  isUntitled               14528 non-null  float64
#  31  isNumbered               14531 non-null  float64
#  32  log10(normalized_price)  14537 non-null  float64
# dtypes: float64(5), int64(15), object(13)
# memory usage: 3.7+ MB

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(data, test_size=0.2)

train_label = train_set["log10(normalized_price)"]
test_label = test_set["log10(normalized_price)"]

train_set = train_set.drop(columns=["log10(normalized_price)"]).copy()
test_set = test_set.drop(columns=["log10(normalized_price)"]).copy()

# %%
data_num = train_set.select_dtypes(include=['int64', 'float64'])
data_cat = train_set.select_dtypes(include='object')

# %%
data_num.describe()
# Out:
#                Sign          Nazi        Framed      square_m  ExhibitedNum  \
# count  11629.000000  11629.000000  11629.000000  11629.000000  11629.000000
# mean       0.873936      0.005847      0.226761      0.549634      1.069309
# std        0.331936      0.076248      0.418755      0.987993      2.385315
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      0.000000      0.129000      0.000000
# 50%        1.000000      0.000000      0.000000      0.308900      0.000000
# 75%        1.000000      0.000000      0.000000      0.607600      1.000000
# max        1.000000      1.000000      1.000000     28.000000     39.000000
#
#        ProvenanceNum  LiteratureNum  CataloguingLength  date_of_birth  \
# count   11629.000000   11629.000000       11629.000000   11629.000000
# mean        2.317654       0.988133           9.911686    1889.369679
# std         2.657113       1.970420         236.012444      53.589084
# min         0.000000       0.000000           0.000000    1292.000000
# 25%         0.000000       0.000000           0.000000    1876.000000
# 50%         2.000000       0.000000           0.000000    1893.000000
# 75%         4.000000       1.000000           0.000000    1923.000000
# max        21.000000      44.000000       17296.000000    1965.000000
#
#        date_of_death       century   repeat_sale  number_of_day         month  \
# count   10767.000000  11629.000000  11629.000000   11629.000000  11629.000000
# mean     1960.888827     19.850202      0.925101     188.304239      6.765156
# std        53.477907      0.591263      0.263240      99.840414      3.275815
# min      1336.000000     14.000000      0.000000      18.000000      1.000000
# 25%      1954.000000     20.000000      1.000000      97.000000      4.000000
# 50%      1973.000000     20.000000      1.000000     171.000000      6.000000
# 75%      1987.000000     20.000000      1.000000     292.000000     10.000000
# max      2019.000000     21.000000      1.000000     354.000000     12.000000
#
#                year  hasFollowers      hasAfter    isUntitled    isNumbered
# count  11629.000000  11629.000000  11629.000000  11622.000000  11624.000000
# mean    2012.734887      0.015307      0.743228      0.085269      0.255162
# std        4.495035      0.122774      0.436871      0.279294      0.435971
# min     2000.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2009.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2013.000000      0.000000      1.000000      0.000000      0.000000
# 75%     2017.000000      0.000000      1.000000      0.000000      1.000000
# max     2020.000000      1.000000      1.000000      1.000000      1.000000

# %%
fig, ax = plt.subplots(figsize=(20,12))
sns.heatmap(data_num.corr(), annot = True, fmt='.1g')
plt.show()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer


num_pipeline = Pipeline([
('selector', DataFrameSelector(data_num.columns)),
('imputer', SimpleImputer(strategy="median")),
('std_scaler', StandardScaler()),
])

# %%
from sklearn.base import BaseEstimator, TransformerMixin
    
class CreateDummies(BaseEstimator, TransformerMixin):
    def __init__(self,):
        pass
    def fit(self, X):
        return self
    def transform(self, X):
        return pd.get_dummies(pd.DataFrame(X)).values

class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values

# %%
cat_pipeline = Pipeline([
('selector', DataFrameSelector(data_cat.columns)),
('create_dummies', CreateDummies()),
])

# %%
from sklearn.pipeline import FeatureUnion

full_pipeline = FeatureUnion(transformer_list=[
("num_pipeline", num_pipeline),
("cat_pipeline", cat_pipeline),
])

# %%
data_prepared = full_pipeline.fit_transform(train_set)
np.shape(data_prepared)
# Out:
# (11629, 8958)
